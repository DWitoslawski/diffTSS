# %%
import os

# %%
os.chdir('/home/witoslaw/diffTSS/train_eval_comparison/')
os.getcwd()
# Out:
# '/home/witoslaw/diffTSS/train_eval_comparison'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
training_results = pd.read_csv('K562_rna_encoding_v_no_encoding.txt', header=None)

# %%
training_results.mean()
# Out:
# 0    0.718388
# 1    0.718147
# dtype: float64

# %%
training_results.std()
# Out:
# 0    0.020065
# 1    0.020597
# dtype: float64
