# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/home/witoslaw/OLD-difftss-DATA-ONLY'

# %%
split = pd.read_csv('split.txt')
split
# Out:
#               Ensembl_ID  fold1  fold2  fold3  fold4  fold5  fold6  fold7  \
# 0        ENSG00000000003  train  train  train  train  train  train  valid
# 1      ENSG00000000003_1  train  train  train  train  train  train  valid
# 2        ENSG00000000005  train  train  train  train  train  train  valid
# 3      ENSG00000000005_1  train  train  train  train  train  train  valid
# 4        ENSG00000000419  train  train  train  train  train  valid   test
# ...                  ...    ...    ...    ...    ...    ...    ...    ...
# 28365    ENSG00000310521  train  train  train  train  train  train  train
# 28366    ENSG00000310523  valid   test  train  train  train  train  train
# 28367  ENSG00000310523_1  valid   test  train  train  train  train  train
# 28368    ENSG00000310526   test  train  train  train  train  train  train
# 28369    ENSG00000310537  train  train  train  train  train  valid   test
#
#        fold8  fold9 fold10 fold11 fold12
# ...

# %%
len(split[split['fold1'] == 'test']) / 16
# Out:
# 174.125
